# %%
import imageio
import numpy as np
import matplotlib.pyplot as plt

# %%
idx = [0]
idx_h = [16]
idx_toes = [11,12]
idx_fingers = [23,24]
idx_Ulegs = [2,3]
idx_LLegs = [5,6]
idx_torso = [1,4,7,10]
idx_feets = [8,9]
idx_shoulders =  [14,15]
idx_upperarm = [17,18]
idx_lowerarm = [19,20]
idx_hands = [21,22]
idx_neck  =[13]

# %% [markdown]
# ## 01

# %%
loss_val = np.load("./final_final_1/train/loss.npy")

# %%
fig1,ax1 =plt.subplots(figsize=(8,8))
l = ax1.plot(range(0,50),loss_val[:,0], label="validation loss",lw=4)
#l_v =ax1.plot(range(0,40020,10),loss[:,1],label = "training loss",lw=0.5)
ax1.set_ylabel("loss")
ax1.set_xlabel("steps")

ax2 = ax1.twinx()
#m = ax2.plot(range(0,40020,10),loss[:,3], 'r', label="mIoU training")
a = ax2.plot(range(0,50),loss_val[:,1], 'g', label = "mIoU validation")
ax2.set_ylabel("metrics")

fig1.legend(loc="center")
plt.savefig("./final_final_1/loss_plot_GTnormal.jpg")

# %%
loss_val[4]
# Out:
# array([0.10625418, 0.26357934, 0.95206964, 0.74504644, 0.99690293,
#        0.79642004, 0.3932295 , 0.63472417, 0.48304818, 0.41959101,
#        0.44123851, 0.43858288, 0.18230001, 0.40457979, 0.58430353,
#        0.        , 0.00102041, 0.49583397, 0.29408   , 0.53345601,
#        0.79094654, 0.42613636, 0.54262379, 0.22456045, 0.23285707,
#        0.0826191 , 0.08667776, 0.03403883, 0.04807528])

# %%
print(loss_val[-1][4:][idx])
print(np.mean(loss_val[-1][4:][idx_h]))
print(np.mean(loss_val[-1][4:][idx_torso]))
print(np.mean(loss_val[-1][4:][idx_Ulegs]))
print(np.mean(loss_val[-1][4:][idx_LLegs]))
print(np.mean(loss_val[-1][4:][idx_neck]))
print(np.mean(loss_val[-1][4:][idx_shoulders]))
print(np.mean(loss_val[-1][4:][idx_upperarm]))
print(np.mean(loss_val[-1][4:][idx_lowerarm]))
print(np.mean(loss_val[-1][4:][idx_feets]))
print(np.mean(loss_val[-1][4:][idx_hands]))
print(np.mean(loss_val[-1][4:][idx_fingers]))
print(np.mean(loss_val[-1][4:][idx_toes]))
# Out:
# [0.99771438]
# 0.7454309233929772
# 0.7043404708271122
# 0.7997500116805802
# 0.782311420342611
# 0.5482701912060339
# 0.44784164072404087
# 0.4944351706023561
# 0.5229813494137454
# 0.4861969954251467
# 0.4105235503493687
# 0.31382279185283035
# 0.31453501719352167

# %% [markdown]
# ### On test

# %%
test = np.load("./final_final_1/testloss.npy")

# %%
test
# Out:
# array([0.63242829, 0.98808905,        nan, 0.99753459, 0.40694661,
#        0.3865909 , 0.37797675, 0.3830978 , 0.39622533, 0.36776817,
#        0.35925564, 0.34397925, 0.33110282, 0.38008052, 0.20193736,
#        0.17846734, 0.32157774, 0.29458591, 0.24052135, 0.43222234,
#        0.3182946 , 0.2643418 , 0.32347373, 0.27704276, 0.25830115,
#        0.22250084, 0.19035596, 0.17090344])

# %%
len(test[1:])
# Out:
# 27

# %%
print(test[3:][idx])
print(np.mean(test[3:][idx_h]))
print(np.mean(test[3:][idx_torso]))
print(np.mean(test[3:][idx_Ulegs]))
print(np.mean(test[3:][idx_LLegs]))
print(np.mean(test[3:][idx_neck]))
print(np.mean(test[3:][idx_shoulders]))
print(np.mean(test[3:][idx_upperarm]))
print(np.mean(test[3:][idx_lowerarm]))
print(np.mean(test[3:][idx_feets]))
print(np.mean(test[3:][idx_hands]))
print(np.mean(test[3:][idx_fingers]))
print(np.mean(test[3:][idx_toes]))
# Out:
# [0.99753459]
# 0.4322223413683898
# 0.38234514085578397
# 0.38228382741863787
# 0.381996748174741
# 0.32157774030169045
# 0.2675536307488846
# 0.2913182026708932
# 0.30025824687611746
# 0.33754103743965047
# 0.24040099499599882
# 0.18062970442318182
# 0.1902023476731859

# %% [markdown]
# # 02

# %%
loss_val = np.load("./best_resolutions/train/loss.npy")

# %%
fig1,ax1 =plt.subplots(figsize=(8,8))
l = ax1.plot(range(0,150),loss_val[:,0], label="validation loss",lw=4)
#l_v =ax1.plot(range(0,40020,10),loss[:,1],label = "training loss",lw=0.5)
ax1.set_ylabel("loss")
ax1.set_xlabel("steps")

ax2 = ax1.twinx()
#m = ax2.plot(range(0,40020,10),loss[:,3], 'r', label="mIoU training")
a = ax2.plot(range(0,150),loss_val[:,1], 'g', label = "mIoU validation")
ax2.set_ylabel("metrics")

fig1.legend(loc="center")
plt.savefig("./final_2_remake/loss_plot_GTamplified.jpg")

# %%
loss_val[-1]
# Out:
# array([9.76406027e-01, 1.62294403e-01, 9.05846059e-01, 6.19864275e-01,
#        9.90995126e-01, 5.56639150e-01, 4.59714003e-01, 3.31170191e-01,
#        3.57223330e-01, 6.57894737e-04, 4.13223140e-04, 2.93841607e-01,
#        0.00000000e+00, 0.00000000e+00, 2.00441329e-01, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.29449838e-03, 2.92275574e-03,
#        0.00000000e+00, 4.17979666e-02, 2.26171244e-03, 2.09340532e-01,
#        1.76291422e-01, 1.24609208e-01, 1.84713039e-02, 0.00000000e+00,
#        0.00000000e+00])

# %%
print(loss_val[-1][4:][idx])
print(np.mean(loss_val[-1][4:][idx_h]))
print(np.mean(loss_val[-1][4:][idx_torso]))
print(np.mean(loss_val[-1][4:][idx_Ulegs]))
print(np.mean(loss_val[-1][4:][idx_LLegs]))
print(np.mean(loss_val[-1][4:][idx_neck]))
print(np.mean(loss_val[-1][4:][idx_shoulders]))
print(np.mean(loss_val[-1][4:][idx_upperarm]))
print(np.mean(loss_val[-1][4:][idx_lowerarm]))
print(np.mean(loss_val[-1][4:][idx_feets]))
print(np.mean(loss_val[-1][4:][idx_hands]))
print(np.mean(loss_val[-1][4:][idx_fingers]))
print(np.mean(loss_val[-1][4:][idx_toes]))
# Out:
# [0.99099513]
# 0.0
# 0.3520363537600081
# 0.39544209660953744
# 0.0005355589386689865
# 0.0
# 0.002108627061502186
# 0.022029839542388983
# 0.1928159767840573
# 0.0
# 0.07154025613858789
# 0.0
# 0.0

# %%
np.mean(loss_val[-1][4:])
# Out:
# 0.15072341003127718

# %% [markdown]
# ### On test

# %%
test = np.load("./final_2_remake/testloss.npy")

# %%
test
# Out:
# array([0.35200579, 0.93598042, 0.78967903, 0.97976481, 0.74527984,
#        0.61366738, 0.51004086, 0.52703282, 0.46756204, 0.37537375,
#        0.52711861, 0.35562947, 0.21499495, 0.49823443, 0.08883716,
#        0.0419605 , 0.28572252, 0.29164455, 0.23860248, 0.50353423,
#        0.36203213, 0.31417082, 0.44076618, 0.3762178 , 0.30358853,
#        0.24475532, 0.17057882, 0.14874279])

# %% [markdown]
# ## With head

# %%
loss_val = np.load("./best_head/train/loss.npy")

# %%
fig1,ax1 =plt.subplots(figsize=(8,8))
l = ax1.plot(range(0,150),loss_val[:150,0], label="validation loss",lw=4)
#l_v =ax1.plot(range(0,40020,10),loss[:,1],label = "training loss",lw=0.5)
ax1.set_ylabel("loss")
ax1.set_xlabel("steps")

ax2 = ax1.twinx()
#m = ax2.plot(range(0,40020,10),loss[:,3], 'r', label="mIoU training")
a = ax2.plot(range(0,150),loss_val[:150,1], 'g', label = "mIoU validation")
ax2.set_ylabel("metrics")

fig1.legend(loc="center")
plt.savefig("./final_whead/loss_plot_GTnormal.jpg")

# %%
loss_val[-3, :4]
# Out:
# array([0.09855828, 0.58052099, 0.97180927, 0.96054386])

# %%
print(loss_val[-1][4:][idx])
print(np.mean(loss_val[-1][4:][idx_h]))
print(np.mean(loss_val[-1][4:][idx_torso]))
print(np.mean(loss_val[-1][4:][idx_Ulegs]))
print(np.mean(loss_val[-1][4:][idx_LLegs]))
print(np.mean(loss_val[-1][4:][idx_neck]))
print(np.mean(loss_val[-1][4:][idx_shoulders]))
print(np.mean(loss_val[-1][4:][idx_upperarm]))
print(np.mean(loss_val[-1][4:][idx_lowerarm]))
print(np.mean(loss_val[-1][4:][idx_feets]))
print(np.mean(loss_val[-1][4:][idx_hands]))
print(np.mean(loss_val[-1][4:][idx_fingers]))
print(np.mean(loss_val[-1][4:][idx_toes]))
# Out:
# [0.99762077]
# 0.933850543532895
# 0.793898684783417
# 0.8576832481710259
# 0.8600699651667405
# 0.597225576854097
# 0.591669924774487
# 0.7119916708280296
# 0.7068520271353345
# 0.5308089244851965
# 0.5573191758208004
# 0.3575423065982837
# 0.2785221195214458

# %%
np.mean(loss_val[-1][4:])
# Out:
# 0.6643684141014531

# %% [markdown]
# ### On test

# %%
test = np.load("./final_whead/testloss.npy")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-25-31487e5fc6ca> in <module>()
# ----> 1 test = np.load("./final_whead/testloss.npy")
#
# ~/.virtualenvs/cv/lib/python3.6/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     370     own_fid = False
#     371     if isinstance(file, basestring):
# --> 372         fid = open(file, "rb")
#     373         own_fid = True
#     374     elif is_pathlib_path(file):
#
# FileNotFoundError: [Errno 2] No such file or directory: './final_whead/testloss.npy'

# %%
test
# Out:
# array([0.35200579, 0.93598042, 0.78967903, 0.97976481, 0.74527984,
#        0.61366738, 0.51004086, 0.52703282, 0.46756204, 0.37537375,
#        0.52711861, 0.35562947, 0.21499495, 0.49823443, 0.08883716,
#        0.0419605 , 0.28572252, 0.29164455, 0.23860248, 0.50353423,
#        0.36203213, 0.31417082, 0.44076618, 0.3762178 , 0.30358853,
#        0.24475532, 0.17057882, 0.14874279])

# %% [markdown]
# # no head

# %%
loss_val = np.load("./best_nohead/train/loss.npy")

# %%
fig1,ax1 =plt.subplots(figsize=(8,8))
l = ax1.plot(range(0,150),loss_val[:,0], label="validation loss",lw=4)
#l_v =ax1.plot(range(0,40020,10),loss[:,1],label = "training loss",lw=0.5)
ax1.set_ylabel("loss")
ax1.set_xlabel("steps")

ax2 = ax1.twinx()
#m = ax2.plot(range(0,40020,10),loss[:,3], 'r', label="mIoU training")
a = ax2.plot(range(0,150),loss_val[:,1], 'g', label = "mIoU validation")
ax2.set_ylabel("metrics")

fig1.legend(loc="center")
plt.savefig("./final_nhead/loss_plot_GTnormal.jpg")

# %%
loss_val[-1]
# Out:
# array([0.03244377, 0.63194132, 0.98754841, 0.95246459, 0.99827244,
#        0.33656966, 0.37903416, 0.37269661, 0.3230951 , 0.37931647,
#        0.37265293, 0.31234285, 0.31620874, 0.36127341, 0.33323856,
#        0.08139535, 0.20915068, 0.30463204, 0.1322869 , 0.3227325 ,
#        0.37812649, 0.14252144, 0.34330365, 0.0769802 , 0.30060355,
#        0.03365854, 0.16365092, 0.        , 0.11947679])

# %%
print(loss_val[-1][4:][idx])
print(np.mean(loss_val[-1][4:][idx_h]))
print(np.mean(loss_val[-1][4:][idx_torso]))
print(np.mean(loss_val[-1][4:][idx_Ulegs]))
print(np.mean(loss_val[-1][4:][idx_LLegs]))
print(np.mean(loss_val[-1][4:][idx_neck]))
print(np.mean(loss_val[-1][4:][idx_shoulders]))
print(np.mean(loss_val[-1][4:][idx_upperarm]))
print(np.mean(loss_val[-1][4:][idx_lowerarm]))
print(np.mean(loss_val[-1][4:][idx_feets]))
print(np.mean(loss_val[-1][4:][idx_hands]))
print(np.mean(loss_val[-1][4:][idx_fingers]))
print(np.mean(loss_val[-1][4:][idx_toes]))
# Out:
# [0.99827244]
# 0.37812649130323284
# 0.32631154069066537
# 0.37586538693445903
# 0.3759846998657774
# 0.3046320394055044
# 0.22750969884323013
# 0.24291254279338126
# 0.1887918733884913
# 0.33874107607802745
# 0.09865472755333637
# 0.059738393515106854
# 0.1452730120163303

# %%
np.mean(loss_val[-1][4:])
# Out:
# 0.2837287981231248

# %% [markdown]
# ### On test

# %%
test = np.load("./test_nohead/logs_hour/testloss.npy")

# %%
test
# Out:
# array([0.29826182, 0.9587305 , 0.55281829, 0.99397858, 0.11265376,
#        0.12837104, 0.08375915, 0.11053454, 0.17738991, 0.11100778,
#        0.15341505, 0.14370196, 0.09765922, 0.19893334, 0.07922392,
#        0.0418518 , 0.18495511, 0.18443092, 0.11988644, 0.2920742 ,
#        0.17401525, 0.11016055, 0.16732386, 0.1128315 , 0.09418506,
#        0.06386985, 0.09280235, 0.05955891])

# %% [markdown]
# ## Mixed

# %%
loss_val = np.load("./best_nohead/train/loss.npy")
loss_wval = np.load("./best_head/train/loss.npy")
loss_rval = np.load("./best_resolutions/train/loss.npy")


fig1,ax1 =plt.subplots(figsize=(8,8))
l = ax1.plot(range(0,150),loss_val[:,0], label="validation loss no head",lw=4, c='g', linestyle="--")
lw = ax1.plot(range(0,150),loss_wval[:150,0], label="validation loss with head",lw=4, c = 'b', linestyle="--")
l_v =ax1.plot(range(0,150),loss_rval[:,0],label = "validation loss_resolution",lw=4, c = 'r', linestyle="--")
ax1.set_ylabel("Loss", fontsize = 20)
ax1.set_xlabel("Epoch", fontsize = 20)
ax1.tick_params(axis='both', which='major', labelsize=15)

ax2 = ax1.twinx()
m = ax2.plot(range(0,150),loss_rval[:,1], 'r', label="mIoU training resolution")
a = ax2.plot(range(0,150),loss_val[:,1], 'g', label = "mIoU validation no head")
b = ax2.plot(range(0,150),loss_wval[:150,1], 'b', label = "mIoU validation with head")
ax2.set_ylabel("mIoU", fontsize=20)
ax2.tick_params(axis='both', which='major', labelsize=15)

#fig1.legend(loc="upper center")
plt.savefig("./loss_plot_GTnormal.jpg")

# %% [markdown]
# IMages

# %%
import tensorflow as tf
from imageio import imread,imsave
import matplotlib.pyplot as plt
# Out:
# /home/blue/.virtualenvs/cv/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
label_colours = [[0, 0, 0], [153, 76, 0], [153, 153, 0]
                # 0 = road, 1 = sidewalk, 2 = building
                ,[76, 153, 0], [0, 153, 0], [0, 153, 76]
                # 3 = wall, 4 = fence, 5 = pole
                ,[0,153, 153], [0, 76, 153], [0, 0, 153]
                # 6 = traffic light, 7 = traffic sign, 8 = vegetation
                ,[76, 0, 153], [153, 0, 153], [153, 0, 76]
                # 9 = terrain, 10 = sky, 11 = person
                ,[255, 51, 51], [255, 153, 51], [255, 255, 51]
                # 12 = rider, 13 = car, 14 = truck
                ,[153, 255, 51], [51, 255, 51], [51, 255, 153]
                # 15 = bus, 16 = train, 17 = motocycle
                ,[51, 255, 255], [51,153,255],[51,51,255],[153,51,255],[255,52,255],[255,52,153], [192,192,192]]
                # 18 = bicycle

# %%
np.matrix(label_colours).shape
# Out:
# (25, 3)

# %%
def decode_labels(mask, img_shape, num_classes):

    color_table = label_colours

    color_mat = tf.constant(color_table, dtype=tf.float32)
    onehot_output = tf.one_hot(mask, depth=num_classes)
    onehot_output = tf.reshape(onehot_output, (-1, num_classes))
    pred = tf.matmul(onehot_output, color_mat)
    pred = tf.cast(tf.reshape(pred, (img_shape[0], img_shape[1], 3)),tf.uint8)
    
    return pred

# %%
im_1 = imread("../../segnet/results/photos/ung_104_36_c0011_segm_7.png")
im_2 = imread("../../segnet/results/photos/36_10_c0019_segm_10.png")
im_3 = imread("../../segnet/results/photos/40_02_c0011_segm_19.png")
im_4 = imread("../../segnet/results/photos/104_52_c0002_segm_64.png")
im_1.shape
# Out:
# (320, 320)

# %%
"../../segnet/results/photos/"

# %%
"../../SURREAL/cmu/cluster_mod_test_heal/annotations/

# %%
im_1[180:190,120:130]
# Out:
# Image([[ 0,  0, 23, 23, 23,  0, 23, 23, 23,  2],
#        [ 0,  0,  0, 23, 23,  0,  2, 23, 23, 23],
#        [ 0,  0,  0, 23, 23,  0,  2, 23, 23, 23],
#        [ 0,  0,  0,  0,  0,  0,  2,  2,  2, 23],
#        [ 0,  0,  0,  0,  0,  0,  2,  2,  2, 23],
#        [ 0,  0,  0,  0,  0,  0,  2,  2,  2,  2],
#        [ 0,  0,  0,  0,  0,  0,  2,  2,  2,  2],
#        [ 0,  0,  0,  0,  0,  0,  2,  2,  2,  2],
#        [ 0,  0,  0,  0,  0,  0,  2,  2,  2,  2],
#        [ 0,  0,  0,  0,  0,  0,  2,  2,  2,  2]], dtype=uint8)

# %%
n_classes=25

# %%
im1 = decode_labels(im_1,im_1.shape, 25)
im2 = decode_labels(im_2,im_2.shape, 25)
im3 = decode_labels(im_3,im_3.shape, 25)
im4 = decode_labels(im_4,im_4.shape, 25)

# %%
with tf.Session() as sess:
    f_im1= sess.run(im1)
    f_im2= sess.run(im2)
    f_im3= sess.run(im3)
    f_im4= sess.run(im4)
    
imsave("../../written/final/Figures/ung_104_36_c0011_segm_7_seg.png",f_im1)
imsave("../../written/final/Figures/36_10_c0019_segm_10_seg.png",f_im2)
imsave("../../written/final/Figures/40_02_c0011_segm_19_seg.png",f_im3)
imsave("../../written/final/Figures/104_52_c0002_segm_64_seg.png",f_im4)
